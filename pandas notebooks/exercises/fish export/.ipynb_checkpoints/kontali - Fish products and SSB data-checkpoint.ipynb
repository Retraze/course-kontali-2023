# %%
# We start by importing pandas and creating a Path object that points to our files.
import pandas as pd
from pathlib import Path

dirpath = Path("../../datasets/kontali")

# %% [markdown]
# # Product
#
# ### Read the file `product.csv` into a pandas DataFrame
#
# Hints:
# 1. the function to use here is `pd.read_csv`
# 1. we can specify the path to `product.csv` with `os.path.join` or `pathlib.Path` from the builtin modules
# 1. we must use the keyword argument `encoding="latin-1"`
# 1. we want to set the index to be the `Product_Code` column
# 1. we also want to set the `delimiter` keyword argument

# %%
df_product = pd.read_csv(dirpath / "product.csv",
                         encoding="latin-1", 
                         delimiter=";", 
                         index_col="Product_Code",
                        )
df_product.head()
# Out:
#               ProductID Country_Code      Product_Description_KA Species_Code  \
# Product_Code
# 3031100               1           NO              Frozen sockeye          SOC
# 3045202               2           NO           Fresh trout, else          TRR
# 3054100               3           NO               Smoked salmon          SAL
# 16041101              4           NO          Brine cured salmon          SAL
# 16041102              5           NO  Salmon in airtight package          SAL
#
#              Presentation Preservation Preparation
# Product_Code
# 3031100               NaN          FRO         NaN
# 3045202               OTH          FRE         NaN
# 3054100               NaN          PRS         SMO
# 16041101              OTH          PRS         BRI
# 16041102              OTH          PRS         BRI

# %% [markdown]
# ### How many product categories are there?

# %%
len(df_product), df_product.shape
# Out:
# (31, (31, 7))

# %% [markdown]
# ### Make a selection dataframe that only contains trout products

# %%
df_product.loc[df_product["Species_Code"] == "TRR"]
# Out:
#               ProductID Country_Code  \
# Product_Code
# 3045202               2           NO
# 3021111               9           NO
# 3021119              10           NO
# 3054300              15           NO
# 3031411              18           NO
# 3031419              19           NO
# 3044200              22           NO
# 3048200              25           NO
# 3019100              27           NO
#
#                                          Product_Description_KA Species_Code  \
# Product_Code
# 3045202                                       Fresh trout, else          TRR
# 3021111                                   Fresh trout (head on)          TRR
# 3021119                                  Fresh trout (head off)          TRR
# 3054300                                            Smoked Trout          TRR
# 3031411                                  Frozen trout (head on)          TRR
# 3031419                                 Frozen trout (head off)          TRR
# 3044200                                     Fresh trout fillets          TRR
# 3048200                                    Frozen trout fillets          TRR
# 3019100       Live, trout (Salmo trutta, Oncorhynchus mykiss...          TRR
#
#              Presentation Preservation Preparation
# Product_Code
# 3045202               OTH          FRE         NaN
# 3021111               WHL          FRE         NaN
# 3021119               WHL          FRE         NaN
# 3054300               NaN          PRS         SMO
# 3031411               WHL          FRO         NaN
# 3031419               WHL          FRO         NaN
# 3044200               FIL          FRE         NaN
# 3048200               FIL          FRO         NaN
# 3019100               NaN          ALI         NaN

# %% [markdown]
# ### Sort dataframe by product code

# %%
df_product.sort_index()
# Out:
#               ProductID Country_Code  \
# Product_Code
# 3019100              27           NO
# 3019901              28           NO
# 3019906              29           NO
# 3021111               9           NO
# 3021119              10           NO
# 3021190               7           NO
# 3021300              11           NO
# 3021411              12           NO
# 3021419              13           NO
# 3021490              14           NO
# 3021901              30           NO
# 3031100               1           NO
# 3031311              16           NO
# 3031319              17           NO
# 3031411              18           NO
# 3031419              19           NO
# 3031490              20           NO
# 3039901              26           NO
# 3044100              21           NO
# 3044200              22           NO
# 3045200              23           NO
# 3045202               2           NO
# 3048100              24           NO
# 3048200              25           NO
# 3049903               8           NO
# 3049991             287           NO
# 3054100               3           NO
# 3054300              15           NO
# 16041101              4           NO
# 16041102              5           NO
# 16041109              6           NO
#
#                                          Product_Description_KA Species_Code  \
# Product_Code
# 3019100       Live, trout (Salmo trutta, Oncorhynchus mykiss...          TRR
# 3019901                Salmon (alevin, parr, smolt etc.), live           SAL
# 3019906                  Live, Arctic char (Salvelinus alpinus)          ACH
# 3021111                                   Fresh trout (head on)          TRR
# 3021119                                  Fresh trout (head off)          TRR
# 3021190                                 Fresh trout, not farmed          TRO
# 3021300                                    Fresh Pacific Salmon          ORC
# 3021411                         Fresh Atlantic salmon (head on)          SAL
# 3021419                        Fresh Atlantic salmon (head off)          SAL
# 3021490                                      Fresh salmon, else          SAL
# 3021901       Fresh or chilled, char (Salvelinus spp.), excl...          ACH
# 3031100                                          Frozen sockeye          SOC
# 3031311                        Frozen Atlantic salmon (head on)          SAL
# 3031319                       Frozen Atlantic salmon (head off)          SAL
# 3031411                                  Frozen trout (head on)          TRR
# 3031419                                 Frozen trout (head off)          TRR
# 3031490                          Frozen trout, else, not farmed          TRO
# 3039901                     Biproduct of Frozen Atlantic salmon          SAL
# 3044100                                    Fresh salmon fillets          SAL
# 3044200                                     Fresh trout fillets          TRR
# 3045200                                  Fresh salmonidae, else          SAL
# 3045202                                       Fresh trout, else          TRR
# 3048100                                   Frozen salmon fillets          SAL
# 3048200                                    Frozen trout fillets          TRR
# 3049903                          Frozen salmon, minced fishmeat          SAL
# 3049991                          Frozen salmon, minced fishmeat          SAL
# 3054100                                           Smoked salmon          SAL
# 3054300                                            Smoked Trout          TRR
# 16041101                                     Brine cured salmon          SAL
# 16041102                             Salmon in airtight package          SAL
# 16041109                                    Canned salmon, else          SAL
#
#              Presentation Preservation Preparation
# Product_Code
# 3019100               NaN          ALI         NaN
# 3019901               NaN          ALI         NaN
# 3019906               NaN          ALI         NaN
# 3021111               WHL          FRE         NaN
# 3021119               WHL          FRE         NaN
# 3021190               NaN          FRE         NaN
# 3021300               WHL          FRE         NaN
# 3021411               WHL          FRE         NaN
# 3021419               WHL          FRE         NaN
# 3021490               WHL          FRE         NaN
# 3021901               WHL          FRE         NaN
# 3031100               NaN          FRO         NaN
# 3031311               WHL          FRO         NaN
# 3031319               WHL          FRO         NaN
# 3031411               WHL          FRO         NaN
# 3031419               WHL          FRO         NaN
# 3031490               WHL          FRO         NaN
# 3039901               BYP          FRO         NaN
# 3044100               FIL          FRE         NaN
# 3044200               FIL          FRE         NaN
# 3045200               OTH          FRE         NaN
# 3045202               OTH          FRE         NaN
# 3048100               FIL          FRO         NaN
# 3048200               FIL          FRO         NaN
# 3049903               OTH          FRO         NaN
# 3049991               OTH          FRO         NaN
# 3054100               NaN          PRS         SMO
# 3054300               NaN          PRS         SMO
# 16041101              OTH          PRS         BRI
# 16041102              OTH          PRS         BRI
# 16041109              OTH          PRS         BRI

# %% [markdown]
# ### Sort dataframe by species code (lexicographically)

# %%
df_product.sort_values("Species_Code")
# Out:
#               ProductID Country_Code  \
# Product_Code
# 3019906              29           NO
# 3021901              30           NO
# 3021300              11           NO
# 3031311              16           NO
# 3019901              28           NO
# 3039901              26           NO
# 3048100              24           NO
# 3045200              23           NO
# 3044100              21           NO
# 3031319              17           NO
# 3021490              14           NO
# 3021419              13           NO
# 3049991             287           NO
# 3054100               3           NO
# 3049903               8           NO
# 16041101              4           NO
# 3021411              12           NO
# 16041109              6           NO
# 16041102              5           NO
# 3031100               1           NO
# 3031490              20           NO
# 3021190               7           NO
# 3045202               2           NO
# 3019100              27           NO
# 3021119              10           NO
# 3031419              19           NO
# 3031411              18           NO
# 3021111               9           NO
# 3054300              15           NO
# 3048200              25           NO
# 3044200              22           NO
#
#                                          Product_Description_KA Species_Code  \
# Product_Code
# 3019906                  Live, Arctic char (Salvelinus alpinus)          ACH
# 3021901       Fresh or chilled, char (Salvelinus spp.), excl...          ACH
# 3021300                                    Fresh Pacific Salmon          ORC
# 3031311                        Frozen Atlantic salmon (head on)          SAL
# 3019901                Salmon (alevin, parr, smolt etc.), live           SAL
# 3039901                     Biproduct of Frozen Atlantic salmon          SAL
# 3048100                                   Frozen salmon fillets          SAL
# 3045200                                  Fresh salmonidae, else          SAL
# 3044100                                    Fresh salmon fillets          SAL
# 3031319                       Frozen Atlantic salmon (head off)          SAL
# 3021490                                      Fresh salmon, else          SAL
# 3021419                        Fresh Atlantic salmon (head off)          SAL
# 3049991                          Frozen salmon, minced fishmeat          SAL
# 3054100                                           Smoked salmon          SAL
# 3049903                          Frozen salmon, minced fishmeat          SAL
# 16041101                                     Brine cured salmon          SAL
# 3021411                         Fresh Atlantic salmon (head on)          SAL
# 16041109                                    Canned salmon, else          SAL
# 16041102                             Salmon in airtight package          SAL
# 3031100                                          Frozen sockeye          SOC
# 3031490                          Frozen trout, else, not farmed          TRO
# 3021190                                 Fresh trout, not farmed          TRO
# 3045202                                       Fresh trout, else          TRR
# 3019100       Live, trout (Salmo trutta, Oncorhynchus mykiss...          TRR
# 3021119                                  Fresh trout (head off)          TRR
# 3031419                                 Frozen trout (head off)          TRR
# 3031411                                  Frozen trout (head on)          TRR
# 3021111                                   Fresh trout (head on)          TRR
# 3054300                                            Smoked Trout          TRR
# 3048200                                    Frozen trout fillets          TRR
# 3044200                                     Fresh trout fillets          TRR
#
#              Presentation Preservation Preparation
# Product_Code
# 3019906               NaN          ALI         NaN
# 3021901               WHL          FRE         NaN
# 3021300               WHL          FRE         NaN
# 3031311               WHL          FRO         NaN
# 3019901               NaN          ALI         NaN
# 3039901               BYP          FRO         NaN
# 3048100               FIL          FRO         NaN
# 3045200               OTH          FRE         NaN
# 3044100               FIL          FRE         NaN
# 3031319               WHL          FRO         NaN
# 3021490               WHL          FRE         NaN
# 3021419               WHL          FRE         NaN
# 3049991               OTH          FRO         NaN
# 3054100               NaN          PRS         SMO
# 3049903               OTH          FRO         NaN
# 16041101              OTH          PRS         BRI
# 3021411               WHL          FRE         NaN
# 16041109              OTH          PRS         BRI
# 16041102              OTH          PRS         BRI
# 3031100               NaN          FRO         NaN
# 3031490               WHL          FRO         NaN
# 3021190               NaN          FRE         NaN
# 3045202               OTH          FRE         NaN
# 3019100               NaN          ALI         NaN
# 3021119               WHL          FRE         NaN
# 3031419               WHL          FRO         NaN
# 3031411               WHL          FRO         NaN
# 3021111               WHL          FRE         NaN
# 3054300               NaN          PRS         SMO
# 3048200               FIL          FRO         NaN
# 3044200               FIL          FRE         NaN

# %% [markdown]
# ### Sort dataframe by species code, then presentation, then preservation (lexicographically)

# %%
df_product.sort_values(["Species_Code", "Presentation", "Preservation"])
# Out:
#               ProductID Country_Code  \
# Product_Code
# 3021901              30           NO
# 3019906              29           NO
# 3021300              11           NO
# 3039901              26           NO
# 3044100              21           NO
# 3048100              24           NO
# 3045200              23           NO
# 3049903               8           NO
# 3049991             287           NO
# 16041101              4           NO
# 16041102              5           NO
# 16041109              6           NO
# 3021411              12           NO
# 3021419              13           NO
# 3021490              14           NO
# 3031311              16           NO
# 3031319              17           NO
# 3019901              28           NO
# 3054100               3           NO
# 3031100               1           NO
# 3031490              20           NO
# 3021190               7           NO
# 3044200              22           NO
# 3048200              25           NO
# 3045202               2           NO
# 3021111               9           NO
# 3021119              10           NO
# 3031411              18           NO
# 3031419              19           NO
# 3019100              27           NO
# 3054300              15           NO
#
#                                          Product_Description_KA Species_Code  \
# Product_Code
# 3021901       Fresh or chilled, char (Salvelinus spp.), excl...          ACH
# 3019906                  Live, Arctic char (Salvelinus alpinus)          ACH
# 3021300                                    Fresh Pacific Salmon          ORC
# 3039901                     Biproduct of Frozen Atlantic salmon          SAL
# 3044100                                    Fresh salmon fillets          SAL
# 3048100                                   Frozen salmon fillets          SAL
# 3045200                                  Fresh salmonidae, else          SAL
# 3049903                          Frozen salmon, minced fishmeat          SAL
# 3049991                          Frozen salmon, minced fishmeat          SAL
# 16041101                                     Brine cured salmon          SAL
# 16041102                             Salmon in airtight package          SAL
# 16041109                                    Canned salmon, else          SAL
# 3021411                         Fresh Atlantic salmon (head on)          SAL
# 3021419                        Fresh Atlantic salmon (head off)          SAL
# 3021490                                      Fresh salmon, else          SAL
# 3031311                        Frozen Atlantic salmon (head on)          SAL
# 3031319                       Frozen Atlantic salmon (head off)          SAL
# 3019901                Salmon (alevin, parr, smolt etc.), live           SAL
# 3054100                                           Smoked salmon          SAL
# 3031100                                          Frozen sockeye          SOC
# 3031490                          Frozen trout, else, not farmed          TRO
# 3021190                                 Fresh trout, not farmed          TRO
# 3044200                                     Fresh trout fillets          TRR
# 3048200                                    Frozen trout fillets          TRR
# 3045202                                       Fresh trout, else          TRR
# 3021111                                   Fresh trout (head on)          TRR
# 3021119                                  Fresh trout (head off)          TRR
# 3031411                                  Frozen trout (head on)          TRR
# 3031419                                 Frozen trout (head off)          TRR
# 3019100       Live, trout (Salmo trutta, Oncorhynchus mykiss...          TRR
# 3054300                                            Smoked Trout          TRR
#
#              Presentation Preservation Preparation
# Product_Code
# 3021901               WHL          FRE         NaN
# 3019906               NaN          ALI         NaN
# 3021300               WHL          FRE         NaN
# 3039901               BYP          FRO         NaN
# 3044100               FIL          FRE         NaN
# 3048100               FIL          FRO         NaN
# 3045200               OTH          FRE         NaN
# 3049903               OTH          FRO         NaN
# 3049991               OTH          FRO         NaN
# 16041101              OTH          PRS         BRI
# 16041102              OTH          PRS         BRI
# 16041109              OTH          PRS         BRI
# 3021411               WHL          FRE         NaN
# 3021419               WHL          FRE         NaN
# 3021490               WHL          FRE         NaN
# 3031311               WHL          FRO         NaN
# 3031319               WHL          FRO         NaN
# 3019901               NaN          ALI         NaN
# 3054100               NaN          PRS         SMO
# 3031100               NaN          FRO         NaN
# 3031490               WHL          FRO         NaN
# 3021190               NaN          FRE         NaN
# 3044200               FIL          FRE         NaN
# 3048200               FIL          FRO         NaN
# 3045202               OTH          FRE         NaN
# 3021111               WHL          FRE         NaN
# 3021119               WHL          FRE         NaN
# 3031411               WHL          FRO         NaN
# 3031419               WHL          FRO         NaN
# 3019100               NaN          ALI         NaN
# 3054300               NaN          PRS         SMO

# %% [markdown]
# ### List all the trout product categories by only using the "Product_Description_KA" column?
#
# Do not use the `Species_Code` column for this task.
#
# Hint: it should be sufficient to check if "trout" is mentioned in the `Product_Description_KA` column.

# %%
trout_idx = df_product["Product_Description_KA"].str.contains("trout")

df_product[trout_idx]
# Out:
#               ProductID Country_Code  \
# Product_Code
# 3045202               2           NO
# 3021190               7           NO
# 3021111               9           NO
# 3021119              10           NO
# 3031411              18           NO
# 3031419              19           NO
# 3031490              20           NO
# 3044200              22           NO
# 3048200              25           NO
# 3019100              27           NO
#
#                                          Product_Description_KA Species_Code  \
# Product_Code
# 3045202                                       Fresh trout, else          TRR
# 3021190                                 Fresh trout, not farmed          TRO
# 3021111                                   Fresh trout (head on)          TRR
# 3021119                                  Fresh trout (head off)          TRR
# 3031411                                  Frozen trout (head on)          TRR
# 3031419                                 Frozen trout (head off)          TRR
# 3031490                          Frozen trout, else, not farmed          TRO
# 3044200                                     Fresh trout fillets          TRR
# 3048200                                    Frozen trout fillets          TRR
# 3019100       Live, trout (Salmo trutta, Oncorhynchus mykiss...          TRR
#
#              Presentation Preservation Preparation
# Product_Code
# 3045202               OTH          FRE         NaN
# 3021190               NaN          FRE         NaN
# 3021111               WHL          FRE         NaN
# 3021119               WHL          FRE         NaN
# 3031411               WHL          FRO         NaN
# 3031419               WHL          FRO         NaN
# 3031490               WHL          FRO         NaN
# 3044200               FIL          FRE         NaN
# 3048200               FIL          FRO         NaN
# 3019100               NaN          ALI         NaN

# %% [markdown]
# ### Make a new column named "Head" with a category dtype. Possible values should be YES, NO and UNKNOWN.

# %%
df = df_product.copy()
head_on = df.Product_Description_KA.str.contains("head on")
head_off = df.Product_Description_KA.str.contains("head off")

df["Head"] = pd.Categorical(["unknown"]*len(df), categories=["yes", "no", "unknown"])
df.loc[head_on, "Head"] = "yes"
df.loc[head_off, "Head"] = "no"
df
# Out:
#               ProductID Country_Code  \
# Product_Code
# 3031100               1           NO
# 3045202               2           NO
# 3054100               3           NO
# 16041101              4           NO
# 16041102              5           NO
# 16041109              6           NO
# 3021190               7           NO
# 3049903               8           NO
# 3021111               9           NO
# 3021119              10           NO
# 3021300              11           NO
# 3021411              12           NO
# 3021419              13           NO
# 3021490              14           NO
# 3054300              15           NO
# 3031311              16           NO
# 3031319              17           NO
# 3031411              18           NO
# 3031419              19           NO
# 3031490              20           NO
# 3044100              21           NO
# 3044200              22           NO
# 3045200              23           NO
# 3048100              24           NO
# 3048200              25           NO
# 3039901              26           NO
# 3019100              27           NO
# 3019901              28           NO
# 3019906              29           NO
# 3021901              30           NO
# 3049991             287           NO
#
#                                          Product_Description_KA Species_Code  \
# Product_Code
# 3031100                                          Frozen sockeye          SOC
# 3045202                                       Fresh trout, else          TRR
# 3054100                                           Smoked salmon          SAL
# 16041101                                     Brine cured salmon          SAL
# 16041102                             Salmon in airtight package          SAL
# 16041109                                    Canned salmon, else          SAL
# 3021190                                 Fresh trout, not farmed          TRO
# 3049903                          Frozen salmon, minced fishmeat          SAL
# 3021111                                   Fresh trout (head on)          TRR
# 3021119                                  Fresh trout (head off)          TRR
# 3021300                                    Fresh Pacific Salmon          ORC
# 3021411                         Fresh Atlantic salmon (head on)          SAL
# 3021419                        Fresh Atlantic salmon (head off)          SAL
# 3021490                                      Fresh salmon, else          SAL
# 3054300                                            Smoked Trout          TRR
# 3031311                        Frozen Atlantic salmon (head on)          SAL
# 3031319                       Frozen Atlantic salmon (head off)          SAL
# 3031411                                  Frozen trout (head on)          TRR
# 3031419                                 Frozen trout (head off)          TRR
# 3031490                          Frozen trout, else, not farmed          TRO
# 3044100                                    Fresh salmon fillets          SAL
# 3044200                                     Fresh trout fillets          TRR
# 3045200                                  Fresh salmonidae, else          SAL
# 3048100                                   Frozen salmon fillets          SAL
# 3048200                                    Frozen trout fillets          TRR
# 3039901                     Biproduct of Frozen Atlantic salmon          SAL
# 3019100       Live, trout (Salmo trutta, Oncorhynchus mykiss...          TRR
# 3019901                Salmon (alevin, parr, smolt etc.), live           SAL
# 3019906                  Live, Arctic char (Salvelinus alpinus)          ACH
# 3021901       Fresh or chilled, char (Salvelinus spp.), excl...          ACH
# 3049991                          Frozen salmon, minced fishmeat          SAL
#
#              Presentation Preservation Preparation     Head
# Product_Code
# 3031100               NaN          FRO         NaN  unknown
# 3045202               OTH          FRE         NaN  unknown
# 3054100               NaN          PRS         SMO  unknown
# 16041101              OTH          PRS         BRI  unknown
# 16041102              OTH          PRS         BRI  unknown
# 16041109              OTH          PRS         BRI  unknown
# 3021190               NaN          FRE         NaN  unknown
# 3049903               OTH          FRO         NaN  unknown
# 3021111               WHL          FRE         NaN      yes
# 3021119               WHL          FRE         NaN       no
# 3021300               WHL          FRE         NaN  unknown
# 3021411               WHL          FRE         NaN      yes
# 3021419               WHL          FRE         NaN       no
# 3021490               WHL          FRE         NaN  unknown
# 3054300               NaN          PRS         SMO  unknown
# 3031311               WHL          FRO         NaN      yes
# 3031319               WHL          FRO         NaN       no
# 3031411               WHL          FRO         NaN      yes
# 3031419               WHL          FRO         NaN       no
# 3031490               WHL          FRO         NaN  unknown
# 3044100               FIL          FRE         NaN  unknown
# 3044200               FIL          FRE         NaN  unknown
# 3045200               OTH          FRE         NaN  unknown
# 3048100               FIL          FRO         NaN  unknown
# 3048200               FIL          FRO         NaN  unknown
# 3039901               BYP          FRO         NaN  unknown
# 3019100               NaN          ALI         NaN  unknown
# 3019901               NaN          ALI         NaN  unknown
# 3019906               NaN          ALI         NaN  unknown
# 3021901               WHL          FRE         NaN  unknown
# 3049991               OTH          FRO         NaN  unknown

# %% [markdown]
# ### [Challenging] Can you recreate the "Preservation" column by using the "Product_Description_KA" column and the below dict named `keywords`?
#
# ```python
# keywords = {
#     "PRS": ["brine", "canned", "smoked", "airtight"],
#     "FRO": ["frozen"],
#     "FRE": ["fresh"],
#     "ALI": ["live"],
# }
# ```
#
# We don't have a solution suggestion for this one, you are on your own!
# __Our recommendation is to skip it for now.__

# %%
# Suggestion:
# iterate over keywords keys
# iterate over keyword value list
# look for keyword value element ("brine") with str.contains()

keywords = {
    "PRS": ["brine", "canned", "smoked", "airtight"],
    "FRO": ["frozen"],
    "FRE": ["fresh"],
    "ALI": ["live"],
}

# %% [markdown]
# # SSB

# %% [markdown]
# ### Read the file `ssb_export.csv` into a pandas DataFrame
#
# Hints:
# 1. the function to use here is `pd.read_csv`
# 1. we can specify the path to `ssb_export.csv` with `os.path.join` or `pathlib.Path` from the builtin modules
# 1. we must use the keyword argument `encoding="latin-1"`
# 1. we want to set the index to be the `ID` column
# 1. we also want to set the `delimiter` keyword argument

# %%
df_ssb = pd.read_csv(dirpath / "ssb_export.csv",
                     encoding="latin-1",
                     delimiter=";",
                     index_col="ID"
                    )
df_ssb.tail()
# Out:
#        Vareflyt    År  Måned   Varenr Landkode  Mengde    Verdi
# ID
# 409074  Eksport  2022     11  3054100       DK    1401   303852
# 409080  Eksport  2022     11  3054100       IE     513   127897
# 409097  Eksport  2022     11  3054100       GB      18     5199
# 409111  Eksport  2022     11  3054300       CA   37623  5777040
# 409112  Eksport  2022     11  3054300       DK       4     1855

# %% [markdown]
# ### Use DataFrame.describe() to find the maximum `Mengde` value from all of the records (rows)

# %%
df_ssb.describe()
# Out:
#                 År       Måned        Varenr        Mengde         Verdi
# count   829.000000  829.000000  8.290000e+02  8.290000e+02  8.290000e+02
# mean   2019.963812    6.515078  3.047174e+06  8.835939e+04  7.546352e+06
# std       1.406040    3.398469  8.041952e+03  1.407916e+05  8.907449e+06
# min    2018.000000    1.000000  3.021411e+06  4.000000e+00  1.030000e+03
# 25%    2019.000000    4.000000  3.044200e+06  5.950000e+03  5.358160e+05
# 50%    2020.000000    7.000000  3.048100e+06  4.632100e+04  3.854326e+06
# 75%    2021.000000    9.000000  3.053910e+06  1.276810e+05  1.221873e+07
# max    2022.000000   12.000000  3.054300e+06  1.495443e+06  5.695852e+07

# %% [markdown]
# ### How many transactions are there in total?

# %%
len(df_ssb), df_ssb.shape[0] # use either of the two
# Out:
# (829, 829)

# %% [markdown]
# ### How many columns are there?

# %%
len(df_ssb.columns), df_ssb.shape[1] # use either of the two
# Out:
# (7, 7)

# %% [markdown]
# ### Which years do the transactions cover

# %%
df_ssb.År.unique().tolist()
# Out:
# [2018, 2019, 2020, 2021, 2022]

# %% [markdown]
# ### How many transactions were there in 2020?

# %%
len(df_ssb[df_ssb["År"] == 2020])
# Out:
# 166

# %% [markdown]
# ### What was the largest single transaction in terms of value?

# %%
df_ssb.Verdi.max()
# Out:
# 56958520

# %% [markdown]
# ### What is the ID of this transaction?

# %%
df_ssb.Verdi.idxmax()
# Out:
# 396689

# %% [markdown]
# ### What year was this transaction?
#
# Try to not directly use the ID from previous answer.

# %%
df_ssb.loc[df_ssb.Verdi.idxmax()].År
# Out:
# 2022

# %% [markdown]
# ### Does the dataframe contain both import and export transactions?

# %%
df_ssb.Vareflyt.unique()
# Out:
# array(['Eksport'], dtype=object)

# %% [markdown]
# ### Make a selection of Canadian transactions only

# %%
df_ssb_ca = df_ssb[df_ssb["Landkode"] == "CA"]

# %% [markdown]
# ### Make a selection of Canadian transactions only, for year 2022
#
# And bind the returned dataframe to this variable name: `df_ssb_ca`. It will be used in the succeding cell.

# %%
df_ssb_ca = df_ssb[(df_ssb["År"] == 2022) & (df_ssb["Landkode"] == "CA")]

# %% [markdown]
# ### Calculate the total weight and value of the above selection for each product number ("Varenr")
#
# Hint: You can use `df_ssb_ca.groupby()` to  group the above selection by product number ("Varenr"). You can use the `sum()` aggregator on the `Grouper` object.
#
# __If DataFrame.groupby is not yet been covered, you can skip this task__.

# %%
df_ssb_ca.groupby("Varenr").sum()[["Mengde", "Verdi"]]
# Out:
#           Mengde      Verdi
# Varenr
# 3021411   433021   39012253
# 3048100  1241370  194185004
# 3048200   618391   73877949
# 3054100    17899    3528944
# 3054300   729937  111319345

# %% [markdown]
# ### What was the total export in kg for Smoked salmon in 2020? (Are you able to find it with a single line of code?)

# %%
df_ssb[(df_ssb["Varenr"] == 3054100) & (df_ssb["År"] == 2020)].Mengde.sum()
# Out:
# 75757

# %% [markdown]
# ### Calculate the average price (NOK/kg) for Fresh Pacific Salmon in 2019
#
# Hint: make a `price/kg` column using `df["Verdi"]` and `df["Mengde"]`

# %%
df = df_ssb[(df_ssb["Varenr"] == 3044100) & (df_ssb["År"] == 2019)]
(df["Verdi"] / df["Mengde"]).mean()
# Out:
# 110.12215162574473

# %% [markdown]
# ### Bonus: Make a bar chart of the average price for Fresh Pacific Salmon by year
#
# Assuming that "Verdi" is all in the same currency.
#
# Hint: make a `price/kg` column using `df["Verdi"]` and `df["Mengde"]`

# %%
df = df_ssb[df_ssb["Varenr"] == 3044100].copy()
df["price/kg"] = df["Verdi"] / df["Mengde"]
df.groupby("År").mean()["price/kg"].plot(kind="bar");

# %% [markdown]
# ---
# # Memory usage
#
# https://pandas.pydata.org/docs/user_guide/gotchas.html#dataframe-memory-usage
#
# ### How much memory does this dataframe use?
#
# For this question, you can use `DataFrame.info()` and read the memory usage from there. Alternatively you can use `DataFrame.memory_usage(deep=True).sum()`.
#
# Try `DataFrame.memory_usage().sum()` (without `deep=True`). Why is the reported memory usage lower now?
#
# Hint: look at the official pandas documentation for `DataFrame.memory_usage()`

# %%
df_ssb.memory_usage(deep=True).sum()
# Out:
# 182719

# %% [markdown]
# ### The `Landkode` column has the `object` dtype. How much is the memory usage reduced (in percent) if `Landkode` dtype is changed to `Categorical`?

# %%
mem_obj = df_ssb["Landkode"].memory_usage(deep=True)
mem_cat = df_ssb["Landkode"].astype('category').memory_usage(deep=True)

# reduction in percent for "Landkode" column
100*(1-mem_cat/mem_obj)
# Out:
# 49.06479591308043

# %% [markdown]
# ### The `Vareflyt` column has the `object` dtype. How much is the memory usage reduced (in percent) if `Vareflyt` dtype is changed to `StringDtype`?

# %%
mem_obj = df_ssb["Vareflyt"].memory_usage(deep=True)
mem_str = df_ssb["Vareflyt"].astype("string").memory_usage(deep=True)

# reduction in percent for "Vareflyt" column
100*(1-mem_cat/mem_obj)
# Out:
# 51.162467212463234

# %% [markdown]
# ---

# %% [markdown]
# ### CHALLENGING:
#
# Assuming that the df_product["Verdi"] is in nok and all exports were traded in local recipient currency,  what was the total export value, in the various local currencies, for Smoked salmon in 2020?
#
# We don't have a solution suggestion for this one, you are on your own!
#
# You probably will need to use the currency dataframe found in:
# `course-kontali-2023/pandas notebooks/datasets/kontali/product.csv`.

# %%
# I would start with something like this
df_ssb[(df_ssb["Varenr"] == 3054100) & (df_ssb["År"] == 2022)]
